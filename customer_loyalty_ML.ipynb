# %% [markdown]
# <a href="https://colab.research.google.com/github/SupunGurusinghe/ML-with-superstore-dataset/blob/main/customer_loyalty_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Imports**

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/SupunGurusinghe/customer-loyalty-ML/main/superstore.csv'
df = pd.read_csv(url ,encoding='windows-1252')
df.head()
# Out:
#    RowID         OrderID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 1      2  CA-2016-152156   11/8/2016  11/11/2016    Second Class   CG-12520
# 2      3  CA-2016-138688   6/12/2016   6/16/2016    Second Class   DV-13045
# 3      4  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
# 4      5  US-2015-108966  10/11/2015  10/18/2015  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
#    Region        ProductID         Category SubCategory  \
# 0   South  FUR-BO-10001798        Furniture   Bookcases
# 1   South  FUR-CH-10000454        Furniture      Chairs
# 2    West  OFF-LA-10000240  Office Supplies      Labels
# 3   South  FUR-TA-10000577        Furniture      Tables
# 4   South  OFF-ST-10000760  Office Supplies     Storage
#
#                                          ProductName     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df['OrderDate'] = pd.to_datetime(df['OrderDate'], infer_datetime_format=True)
df['ShipDate'] = pd.to_datetime(df['ShipDate'], infer_datetime_format=True)
df.head()
# Out:
#    RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 0      1  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 1      2  CA-2016-152156 2016-11-08 2016-11-11    Second Class   CG-12520
# 2      3  CA-2016-138688 2016-06-12 2016-06-16    Second Class   DV-13045
# 3      4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
# 4      5  US-2015-108966 2015-10-11 2015-10-18  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
#    Region        ProductID         Category SubCategory  \
# 0   South  FUR-BO-10001798        Furniture   Bookcases
# 1   South  FUR-CH-10000454        Furniture      Chairs
# 2    West  OFF-LA-10000240  Office Supplies      Labels
# 3   South  FUR-TA-10000577        Furniture      Tables
# 4   South  OFF-ST-10000760  Office Supplies     Storage
#
#                                          ProductName     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
import datetime as dt

least_recent_date = df['OrderDate'].min()
most_recent_date = df['OrderDate'].max()

print(f'First day: {least_recent_date} \nLast day: {most_recent_date}')
# Out:
# First day: 2014-01-03 00:00:00
# Last day: 2017-12-30 00:00:00

# %%
df = df[df['OrderDate'].dt.year == 2017]
df.shape[0]
# Out:
# 3312

# %%
df.head()
# Out:
#     RowID         OrderID  OrderDate   ShipDate        ShipMode CustomerID  \
# 12     13  CA-2017-114412 2017-04-15 2017-04-20  Standard Class   AA-10480
# 23     24  US-2017-156909 2017-07-16 2017-07-18    Second Class   SF-20065
# 34     35  CA-2017-107727 2017-10-19 2017-10-23    Second Class   MA-17560
# 41     42  CA-2017-120999 2017-09-10 2017-09-15  Standard Class   LC-16930
# 43     44  CA-2017-139619 2017-09-19 2017-09-23  Standard Class   ES-14080
#
#        CustomerName      Segment        Country          City  ... PostalCode  \
# 12     Andrew Allen     Consumer  United States       Concord  ...      28027
# 23  Sandra Flanagan     Consumer  United States  Philadelphia  ...      19140
# 34     Matt Abelman  Home Office  United States       Houston  ...      77095
# 41   Linda Cazamias    Corporate  United States    Naperville  ...      60540
# 43       Erin Smith    Corporate  United States     Melbourne  ...      32935
#
#      Region        ProductID         Category SubCategory  \
# 12    South  OFF-PA-10002365  Office Supplies       Paper
# 23     East  FUR-CH-10002774        Furniture      Chairs
# 34  Central  OFF-PA-10000249  Office Supplies       Paper
# 41  Central  TEC-PH-10004093       Technology      Phones
# 43    South  OFF-ST-10003282  Office Supplies     Storage
#
#                                           ProductName    Sales  Quantity  \
# 12                                         Xerox 1967   15.552         3
# 23                 Global Deluxe Stacking Chair, Gray   71.372         2
# 34                                  Easy-staple paper   29.472         3
# 41                                 Panasonic Kx-TS550  147.168         4
# 43  Advantus 10-Drawer Portable Organizer, Chrome ...   95.616         2
#
#     Discount   Profit
# 12       0.2   5.4432
# 23       0.3  -1.0196
# 34       0.2   9.9468
# 41       0.2  16.5564
# 43       0.2   9.5616
#
# [5 rows x 21 columns]

# %%
# Recency
date = '2018-01-01'
recency = pd.to_datetime(date).normalize() - df.groupby('CustomerID').agg(Maximum_Date=('OrderDate', np.max))
print(recency)
# Out:
#            Maximum_Date
# CustomerID
# AA-10315       186 days
# AA-10375        21 days
# AA-10480       261 days
# AA-10645        57 days
# AB-10060        56 days
# ...                 ...
# XP-21865        45 days
# YC-21895         6 days
# YS-21880        11 days
# ZC-21910        56 days
# ZD-21925       204 days
#
# [693 rows x 1 columns]

# %%
# Frequency

frequency = df[pd.to_datetime(df['OrderDate']).dt.month == 12].groupby('CustomerID')['RowID'].count()
print(frequency)
# Out:
# CustomerID
# AA-10375    3
# AB-10165    2
# AC-10450    1
# AC-10615    1
# AD-10180    2
#            ..
# VF-21715    1
# VW-21775    3
# WB-21850    2
# YC-21895    1
# YS-21880    1
# Name: RowID, Length: 195, dtype: int64

# %%
# Monetary

monetary = df[pd.to_datetime(df['OrderDate']).dt.month == 12].groupby('CustomerID')['Sales'].sum()
print(monetary)
# Out:
# CustomerID
# AA-10375     149.872
# AB-10165      39.792
# AC-10450    1665.620
# AC-10615      37.930
# AD-10180     916.590
#               ...
# VF-21715      28.160
# VW-21775     678.100
# WB-21850      91.193
# YC-21895     750.680
# YS-21880    1000.020
# Name: Sales, Length: 195, dtype: float64
